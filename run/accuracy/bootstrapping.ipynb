# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
result_dataset_path = "INSERT_YOUR_DATASET_PATH_HERE"
movies = pd.read_csv(result_dataset_path, index_col=0)

# %%
def percent_match(list1, list2):
    """
    Calculate the percentage of matching values between two lists.
    
    Parameters:
    list1 (list): The first list of values.
    list2 (list): The second list of values.
    
    Returns:
    float: The percentage of matching values.
    """
    # Ensure the lists are of the same length
    if len(list1) != len(list2):
        raise ValueError("The two lists must be of the same length")

    # Count the number of matching values
    matches = [1 for a, b in zip(list1, list2) if a == b]

    # Calculate the percentage of matches
    #percent_match = (sum(matches) / len(list1))
    #return percent_match
    return sum(matches)

# %%
movies.columns
# Out:
# Index(['Unnamed: 0',
#        'isuserpublisher_hasannotations_hasmetadata_isofficial_subsetall_isdraft',
#        'licenseurl', 'subsetrateddeduplicated', 'isbestuniquearrangement',
#        'subsetdeduplicated', 'isbestarrangement', 'hascustomvideo',
#        'hascustomaudio', 'license', 'isuserstaff', 'subsetrated', 'haspaywall',
#        'isoriginal', 'isbestpath', 'haslyrics', 'publisher', 'isuserpro',
#        'israted', 'complexity', 'version', 'ncomments', 'ntracks', 'genres',
#        'rating', 'nratings', 'bestpath', 'bestarrangement', 'nfavorites',
#        'songlengthbars', 'bestuniquearrangement', 'groups', 'songlengthbeats',
#        'nannotations', 'grooveconsistency', 'artistname', 'songlength',
#        'scaleconsistency', 'nlyrics', 'songlengthseconds', 'tracks',
#        'composername', 'subtitle', 'tags', 'nviews', 'notesperbar', 'ntokens',
#        'nnotes', 'songname', 'title', 'pitchclassentropy', 'path_metadata',
#        'manual_labels', 'gpt4o', 'llama3-8b', 'llama3-70b'],
#       dtype='object')

# %%
def bootstrap(df, prediction_column: str, N=10000):
    accuracy = []
    for _ in range(N):
        # Randomly sample from df["label"] with replacement
        sample_indices = df['manual_labels'].sample(n=100, replace=True).index
        
        sampled_prediction = df.loc[sample_indices, prediction_column]
        sampled_label = df.loc[sample_indices, 'manual_labels']
        
        accuracy.append(percent_match(list(sampled_prediction), list(sampled_label)))
    return accuracy

# %%
def mean_confidence_interval(data):
    """Calculate mean, p50, p5, and p95 intervals"""
    data = np.array(data)
    mean = np.mean(data)
    median = np.percentile(data, 50)
    lower = np.percentile(data, 5)
    upper = np.percentile(data, 95)
    return mean, median, lower, upper

# %%
model = "gpt4o"
model = "llama3-8b"
model = "llama3-70b"
results = bootstrap(movies, model)
mean_confidence_interval(results)
# Out:
# (91.947, 92.0, 87.0, 96.0)
